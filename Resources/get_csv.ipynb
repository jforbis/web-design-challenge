# %%
import pandas as pd
import datetime as dt

# %%
#
data = pd.read_csv("cities.csv")
data
# Out:
#      City_ID          City  Cloudiness Country        Date  Humidity    Lat  \
# 0          0  jacareacanga           0      BR  1528902000        62  -6.22
# 1          1    kaitangata         100      NZ  1528905304        94 -46.28
# 2          2      goulburn          20      AU  1528905078        91 -34.75
# 3          3          lata          76      IN  1528905305        89  30.78
# 4          4    chokurdakh           0      RU  1528905306        88  70.62
# ..       ...           ...         ...     ...         ...       ...    ...
# 542      542        scalea          36      IT  1528905631       100  39.82
# 543      543    san andres          68      PH  1528905632       100  13.32
# 544      544        muisne          92      EC  1528905633        84   0.61
# 545      545           ati          20      TD  1528905633        25  13.21
# 546      546      san luis           0      AR  1528905472        53 -33.30
#
#         Lng  Max Temp  Wind Speed
# ...

# %%
data = data.drop(columns=["City_ID"])
data
# Out:
#              City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0    jacareacanga           0      BR  1528902000        62  -6.22  -57.76
# 1      kaitangata         100      NZ  1528905304        94 -46.28  169.85
# 2        goulburn          20      AU  1528905078        91 -34.75  149.72
# 3            lata          76      IN  1528905305        89  30.78   78.62
# 4      chokurdakh           0      RU  1528905306        88  70.62  147.90
# ..            ...         ...     ...         ...       ...    ...     ...
# 542        scalea          36      IT  1528905631       100  39.82   15.79
# 543    san andres          68      PH  1528905632       100  13.32  122.68
# 544        muisne          92      EC  1528905633        84   0.61  -80.02
# 545           ati          20      TD  1528905633        25  13.21   18.34
# 546      san luis           0      AR  1528905472        53 -33.30  -66.34
#
#      Max Temp  Wind Speed
# 0       89.60        6.93
# ...

# %%
data_df = data.set_index("City")
data_df
# Out:
#               Cloudiness Country        Date  Humidity    Lat     Lng  \
# City
# jacareacanga           0      BR  1528902000        62  -6.22  -57.76
# kaitangata           100      NZ  1528905304        94 -46.28  169.85
# goulburn              20      AU  1528905078        91 -34.75  149.72
# lata                  76      IN  1528905305        89  30.78   78.62
# chokurdakh             0      RU  1528905306        88  70.62  147.90
# ...                  ...     ...         ...       ...    ...     ...
# scalea                36      IT  1528905631       100  39.82   15.79
# san andres            68      PH  1528905632       100  13.32  122.68
# muisne                92      EC  1528905633        84   0.61  -80.02
# ati                   20      TD  1528905633        25  13.21   18.34
# san luis               0      AR  1528905472        53 -33.30  -66.34
#
#               Max Temp  Wind Speed
# City
# jacareacanga     89.60        6.93
# kaitangata       42.61        5.64
# ...

# %%
data_df["Date"].dt.strftime("%m/%d/%y")
data_df = data_df[["Date", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]]
data_df.head()
# Out:
#                                       Date Country    Lat     Lng  Max Temp  \
# City
# jacareacanga 1899-12-14 12:02:45.900877824      BR  -6.22  -57.76     89.60
# kaitangata   1908-12-31 12:02:45.900877824      NZ -46.28  169.85     42.61
# goulburn     1908-05-19 12:02:45.900877824      AU -34.75  149.72     44.32
# lata         1909-01-01 12:02:45.900877824      IN  30.78   78.62     59.89
# chokurdakh   1909-01-02 12:02:45.900877824      RU  70.62  147.90     32.17
#
#               Humidity  Cloudiness  Wind Speed
# City
# jacareacanga        62           0        6.93
# kaitangata          94         100        5.64
# goulburn            91          20       10.11
# lata                89          76        0.94
# chokurdakh          88           0        2.95

# %%
x = data_df.to_html()
print(x)
# Out:
# d>13.87</td>
#     </tr>
#     <tr>
#       <th>davidson</th>
#       <td>1909-10-23 12:02:45.900877824</td>
#       <td>US</td>
#       <td>35.50</td>
#       <td>-80.85</td>
#       <td>78.80</td>
#       <td>65</td>
#       <td>40</td>
#       <td>4.70</td>
#     </tr>
#     <tr>
#       <th>oksfjord</th>
#       <td>1903-03-29 12:02:45.900877824</td>
#       <td>NO</td>
#       <td>70.24</td>
#       <td>22.35</td>
#       <td>46.40</td>
#       <td>65</td>
#       <td>40</td>
#       <td>10.29</td>
#     </tr>
#     <tr>
#       <th>wattegama</th>
#       <td>1909-07-02 12:02:45.900877824</td>
#       <td>LK</td>
#       <td>7.35</td>
#       <td>80.68</td>
#       <td>71.41</td>
#       <td>97</td>
#       <td>92</td>
#       <td>5.75</td>
#     </tr>
#     <tr>
#       <th>inyonga</th>
#       <td>1909-07-02 12:02:45.900877824</td>
#       <td>TZ</td>
#       <td>-6.72</td>
#       <td>32.06</td>
#       <td>79.42</td>
#       <td>32</td>
#       <td>0</td>
# ...

# %%
data_df.to_html(open("cities.html", "w"))
